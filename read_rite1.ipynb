# %%
import pandas as pd

# %%
pd.read_csv('D:\\DUCAT\\Pandas\\student_results.csv')
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
# 1        1002     10          6             8                       2
# 2        1003     10          3             8                       2
# 3        1004     11          0            10                       1
# 4        1005     11          4             7                       2
# 5        1006     11         10             7                       0
# 6        1007     12          4             6                       0
# 7        1008     12         10             6                       2
# 8        1009     12          2             8                       2
# 9        1010     12          6             9                       1
#
#    Mobile Games hrs  Percantege
# 0                 5          50
# 1                 0          80
# 2                 4          60
# 3                 5          45
# ...

# %%
pd.read_csv('D:\\DUCAT\\Pandas\\Fortune_10.csv')
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill               Health       2009  $10,573,990
# 5   6         Techline               Health       2006  $13,898,119
# 6   7          Cityace               Health       2010   $9,254,614
# 7   8   Kayelectronics               Health       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# ...

# %%
import os 
os.getcwd() # to get the location where the file has been saved
# Out:
# 'C:\\Users\\BHAVNESH\\code_23'

# %%
pd.read_csv('D:\\DUCAT\\Pandas\\Fortune_10.csv',nrows=5)
# Out:
#    ID             Name            Industry  Inception       Revenue  \
# 0   1          Lamtone         IT Services       2009  $11,757,018
# 1   2        Stripfind  Financial Services       2010  $12,329,371
# 2   3  Canecorporation              Health       2012  $10,597,009
# 3   4         Mattouch         IT Services       2013  $14,026,934
# 4   5        Techdrill              Health       2009  $10,573,990
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# 4  7,435,363 Dollars   3138627     8%

# %%
pd.read_csv('D:\\DUCAT\\Pandas\\Fortune_10.csv',usecols=[2,4,6])
# Out:
#               Industry       Revenue    Profit
# 0          IT Services  $11,757,018    5274553
# 1   Financial Services  $12,329,371   11412916
# 2               Health  $10,597,009    3005820
# 3          IT Services  $14,026,934    6597557
# 4               Health  $10,573,990    3138627
# 5               Health  $13,898,119    8427816
# 6               Health   $9,254,614    3005116
# 7               Health   $9,451,943    5573830
# 8          IT Services  $14,001,180   11901180
# 9  Government Services  $11,088,336    5453060

# %%
pd.read_csv('D:\\DUCAT\\Pandas\\Fortune_11.csv')
# Out:
#     0                1                    2     3             4  \
# 0   1          Lamtone          IT Services  2009  $11,757,018
# 1   2        Stripfind   Financial Services  2010  $12,329,371
# 2   3  Canecorporation               Health  2012  $10,597,009
# 3   4         Mattouch          IT Services  2013  $14,026,934
# 4   5        Techdrill               Health  2009  $10,573,990
# 5   6         Techline               Health  2006  $13,898,119
# 6   7          Cityace               Health  2010   $9,254,614
# 7   8   Kayelectronics               Health  2009   $9,451,943
# 8   9          Ganzlax          IT Services  2011  $14,001,180
# 9  10      Trantraxlax  Government Services  2011  $11,088,336
#
#                    5         6    7
# 0  6,482,465 Dollars   5274553  30%
# 1    916,455 Dollars  11412916  20%
# 2  7,591,189 Dollars   3005820   7%
# 3  7,429,377 Dollars   6597557  26%
# 4  7,435,363 Dollars   3138627   8%
# 5  5,470,303 Dollars   8427816  23%
# ...

# %%
pd.read_csv('D:\\DUCAT\\Pandas\\Fortune_11.csv',skiprows=1)
# Out:
#     1          Lamtone          IT Services  2009  $11,757,018   \
# 0   2        Stripfind   Financial Services  2010  $12,329,371
# 1   3  Canecorporation               Health  2012  $10,597,009
# 2   4         Mattouch          IT Services  2013  $14,026,934
# 3   5        Techdrill               Health  2009  $10,573,990
# 4   6         Techline               Health  2006  $13,898,119
# 5   7          Cityace               Health  2010   $9,254,614
# 6   8   Kayelectronics               Health  2009   $9,451,943
# 7   9          Ganzlax          IT Services  2011  $14,001,180
# 8  10      Trantraxlax  Government Services  2011  $11,088,336
#
#    6,482,465 Dollars   5274553  30%
# 0    916,455 Dollars  11412916  20%
# 1  7,591,189 Dollars   3005820   7%
# 2  7,429,377 Dollars   6597557  26%
# 3  7,435,363 Dollars   3138627   8%
# 4  5,470,303 Dollars   8427816  23%
# 5  6,249,498 Dollars   3005116   6%
# 6  3,878,113 Dollars   5573830   4%
# 7                NaN  11901180  18%
# ...

# %%
pd.read_csv('D:\\DUCAT\\Pandas\\Fortune_10.csv')
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill               Health       2009  $10,573,990
# 5   6         Techline               Health       2006  $13,898,119
# 6   7          Cityace               Health       2010   $9,254,614
# 7   8   Kayelectronics               Health       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# ...

# %%
pd.read_csv('D:\\DUCAT\\Pandas\\Fortune_10.csv',index_col='Inception')
# Out:
#            ID             Name             Industry       Revenue  \
# Inception
# 2009        1          Lamtone          IT Services  $11,757,018
# 2010        2        Stripfind   Financial Services  $12,329,371
# 2012        3  Canecorporation               Health  $10,597,009
# 2013        4         Mattouch          IT Services  $14,026,934
# 2009        5        Techdrill               Health  $10,573,990
# 2006        6         Techline               Health  $13,898,119
# 2010        7          Cityace               Health   $9,254,614
# 2009        8   Kayelectronics               Health   $9,451,943
# 2011        9          Ganzlax          IT Services  $14,001,180
# 2011       10      Trantraxlax  Government Services  $11,088,336
#
#                     Expenses    Profit Growth
# Inception
# 2009       6,482,465 Dollars   5274553    30%
# 2010         916,455 Dollars  11412916    20%
# 2012       7,591,189 Dollars   3005820     7%
# ...

# %%
pd.read_csv('D:\\DUCAT\\Pandas\\Fortune_10.csv',index_col=[5])
# Out:
#                    ID             Name             Industry  Inception  \
# Expenses
# 6,482,465 Dollars   1          Lamtone          IT Services       2009
# 916,455 Dollars     2        Stripfind   Financial Services       2010
# 7,591,189 Dollars   3  Canecorporation               Health       2012
# 7,429,377 Dollars   4         Mattouch          IT Services       2013
# 7,435,363 Dollars   5        Techdrill               Health       2009
# 5,470,303 Dollars   6         Techline               Health       2006
# 6,249,498 Dollars   7          Cityace               Health       2010
# 3,878,113 Dollars   8   Kayelectronics               Health       2009
# NaN                 9          Ganzlax          IT Services       2011
# 5,635,276 Dollars  10      Trantraxlax  Government Services       2011
#
#                         Revenue    Profit Growth
# Expenses
# 6,482,465 Dollars  $11,757,018    5274553    30%
# 916,455 Dollars    $12,329,371   11412916    20%
# ...

# %%
pd.read_csv('D:\\DUCAT\\Pandas\\Fortune_10.csv')
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill               Health       2009  $10,573,990
# 5   6         Techline               Health       2006  $13,898,119
# 6   7          Cityace               Health       2010   $9,254,614
# 7   8   Kayelectronics               Health       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# ...

# %%
pd.read_csv('D:\\DUCAT\\Pandas\\Fortune_10.csv',header=1)
# Out:
#     1          Lamtone          IT Services  2009  $11,757,018   \
# 0   2        Stripfind   Financial Services  2010  $12,329,371
# 1   3  Canecorporation               Health  2012  $10,597,009
# 2   4         Mattouch          IT Services  2013  $14,026,934
# 3   5        Techdrill               Health  2009  $10,573,990
# 4   6         Techline               Health  2006  $13,898,119
# 5   7          Cityace               Health  2010   $9,254,614
# 6   8   Kayelectronics               Health  2009   $9,451,943
# 7   9          Ganzlax          IT Services  2011  $14,001,180
# 8  10      Trantraxlax  Government Services  2011  $11,088,336
#
#    6,482,465 Dollars   5274553  30%
# 0    916,455 Dollars  11412916  20%
# 1  7,591,189 Dollars   3005820   7%
# 2  7,429,377 Dollars   6597557  26%
# 3  7,435,363 Dollars   3138627   8%
# 4  5,470,303 Dollars   8427816  23%
# 5  6,249,498 Dollars   3005116   6%
# 6  3,878,113 Dollars   5573830   4%
# 7                NaN  11901180  18%
# ...

# %%
pd.read_csv('D:\\DUCAT\\Pandas\\Fortune_12.csv',header=None)
# Out:
#     0                1                    2     3             4  \
# 0   1          Lamtone          IT Services  2009  $11,757,018
# 1   2        Stripfind   Financial Services  2010  $12,329,371
# 2   3  Canecorporation               Health  2012  $10,597,009
# 3   4         Mattouch          IT Services  2013  $14,026,934
# 4   5        Techdrill               Health  2009  $10,573,990
# 5   6         Techline               Health  2006  $13,898,119
# 6   7          Cityace               Health  2010   $9,254,614
# 7   8   Kayelectronics               Health  2009   $9,451,943
# 8   9          Ganzlax          IT Services  2011  $14,001,180
# 9  10      Trantraxlax  Government Services  2011  $11,088,336
#
#                    5         6    7
# 0  6,482,465 Dollars   5274553  30%
# 1    916,455 Dollars  11412916  20%
# 2  7,591,189 Dollars   3005820   7%
# 3  7,429,377 Dollars   6597557  26%
# 4  7,435,363 Dollars   3138627   8%
# 5  5,470,303 Dollars   8427816  23%
# ...

# %%
pd.read_csv('D:\\DUCAT\\Pandas\\Fortune_12.csv',names =['a','b','c','d','e','f','g','h'])
# Out:
#     a                b                    c     d             e  \
# 0   1          Lamtone          IT Services  2009  $11,757,018
# 1   2        Stripfind   Financial Services  2010  $12,329,371
# 2   3  Canecorporation               Health  2012  $10,597,009
# 3   4         Mattouch          IT Services  2013  $14,026,934
# 4   5        Techdrill               Health  2009  $10,573,990
# 5   6         Techline               Health  2006  $13,898,119
# 6   7          Cityace               Health  2010   $9,254,614
# 7   8   Kayelectronics               Health  2009   $9,451,943
# 8   9          Ganzlax          IT Services  2011  $14,001,180
# 9  10      Trantraxlax  Government Services  2011  $11,088,336
#
#                    f         g    h
# 0  6,482,465 Dollars   5274553  30%
# 1    916,455 Dollars  11412916  20%
# 2  7,591,189 Dollars   3005820   7%
# 3  7,429,377 Dollars   6597557  26%
# 4  7,435,363 Dollars   3138627   8%
# 5  5,470,303 Dollars   8427816  23%
# ...

# %%
df=pd.read_csv('D:\\DUCAT\\Pandas\\Fortune_10.csv')
df
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill               Health       2009  $10,573,990
# 5   6         Techline               Health       2006  $13,898,119
# 6   7          Cityace               Health       2010   $9,254,614
# 7   8   Kayelectronics               Health       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# ...

# %%
df.head()
# Out:
#    ID             Name            Industry  Inception       Revenue  \
# 0   1          Lamtone         IT Services       2009  $11,757,018
# 1   2        Stripfind  Financial Services       2010  $12,329,371
# 2   3  Canecorporation              Health       2012  $10,597,009
# 3   4         Mattouch         IT Services       2013  $14,026,934
# 4   5        Techdrill              Health       2009  $10,573,990
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# 4  7,435,363 Dollars   3138627     8%

# %%
df.tail()
# Out:
#    ID            Name             Industry  Inception       Revenue  \
# 5   6        Techline               Health       2006  $13,898,119
# 6   7         Cityace               Health       2010   $9,254,614
# 7   8  Kayelectronics               Health       2009   $9,451,943
# 8   9         Ganzlax          IT Services       2011  $14,001,180
# 9  10     Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 5  5,470,303 Dollars   8427816    23%
# 6  6,249,498 Dollars   3005116     6%
# 7  3,878,113 Dollars   5573830     4%
# 8                NaN  11901180    18%
# 9  5,635,276 Dollars   5453060     7%

# %%
df.head(3)
# Out:
#    ID             Name            Industry  Inception       Revenue  \
# 0   1          Lamtone         IT Services       2009  $11,757,018
# 1   2        Stripfind  Financial Services       2010  $12,329,371
# 2   3  Canecorporation              Health       2012  $10,597,009
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%

# %%
df.tail(3)
# Out:
#    ID            Name             Industry  Inception       Revenue  \
# 7   8  Kayelectronics               Health       2009   $9,451,943
# 8   9         Ganzlax          IT Services       2011  $14,001,180
# 9  10     Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 7  3,878,113 Dollars   5573830     4%
# 8                NaN  11901180    18%
# 9  5,635,276 Dollars   5453060     7%

# %%
pd.read_csv('D:\\DUCAT\\Pandas\\Fortune_10.csv',dtype= {'Profit': 'float64'})
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill               Health       2009  $10,573,990
# 5   6         Techline               Health       2006  $13,898,119
# 6   7          Cityace               Health       2010   $9,254,614
# 7   8   Kayelectronics               Health       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses      Profit Growth
# 0  6,482,465 Dollars   5274553.0    30%
# 1    916,455 Dollars  11412916.0    20%
# 2  7,591,189 Dollars   3005820.0     7%
# 3  7,429,377 Dollars   6597557.0    26%
# ...

# %%
pd.read_csv('D:\\DUCAT\\Pandas\\Fortune_14.csv')
# Out:
#    ID Values             Name             Industry  Inception       Revenue  \
# 0   1    Yes          Lamtone          IT Services       2009  $11,757,018
# 1   2    Yes        Stripfind   Financial Services       2010  $12,329,371
# 2   3     NO  Canecorporation               Health       2012  $10,597,009
# 3   4    Yes         Mattouch          IT Services       2013  $14,026,934
# 4   5    Yes        Techdrill               Health       2009  $10,573,990
# 5   6    Yes         Techline               Health       2006  $13,898,119
# 6   7     NO          Cityace               Health       2010   $9,254,614
# 7   8    Yes   Kayelectronics               Health       2009   $9,451,943
# 8   9     NO          Ganzlax          IT Services       2011  $14,001,180
# 9  10    Yes      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# ...

# %%
pd.read_csv('D:\\DUCAT\\Pandas\\Fortune_14.csv',true_values=['Yes'],false_values=['NO'])
# Out:
#    ID  Values             Name             Industry  Inception       Revenue  \
# 0   1    True          Lamtone          IT Services       2009  $11,757,018
# 1   2    True        Stripfind   Financial Services       2010  $12,329,371
# 2   3   False  Canecorporation               Health       2012  $10,597,009
# 3   4    True         Mattouch          IT Services       2013  $14,026,934
# 4   5    True        Techdrill               Health       2009  $10,573,990
# 5   6    True         Techline               Health       2006  $13,898,119
# 6   7   False          Cityace               Health       2010   $9,254,614
# 7   8    True   Kayelectronics               Health       2009   $9,451,943
# 8   9   False          Ganzlax          IT Services       2011  $14,001,180
# 9  10    True      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# ...
