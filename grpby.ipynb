# %%
import pandas as pd

# %%
df=pd.read_csv('D:\\DUCAT\\Pandas\\student_result1.csv')
df
# Out:
#    Student ID Section  Class  Study hrs  Social Media usage hrs  Percentage
# 0        1001       A     10          2                       3          50
# 1        1002       B     10          6                       2          80
# 2        1003       A     10          3                       2          60
# 3        1004       C     11          0                       1          45
# 4        1005       C     12          5                       2          75

# %%
gr1=df.groupby('Section')
gr1

# %%
gr2=df.groupby('Section').groups
gr2
# Out:
# {'A': [0, 2], 'B': [1], 'C': [3, 4]}

# %%
for x,y in gr1:
    print(x)
    print(y)
# Out:
# A
#    Student ID Section  Class  Study hrs  Social Media usage hrs  Percentage
# 0        1001       A     10          2                       3          50
# 2        1003       A     10          3                       2          60
# B
#    Student ID Section  Class  Study hrs  Social Media usage hrs  Percentage
# 1        1002       B     10          6                       2          80
# C
#    Student ID Section  Class  Study hrs  Social Media usage hrs  Percentage
# 3        1004       C     11          0                       1          45
# 4        1005       C     12          5                       2          75

# %%
gr1.describe()
# Out:
#         Student ID                                                      \
#              count    mean       std     min      25%     50%      75%
# Section
# A              2.0  1002.0  1.414214  1001.0  1001.50  1002.0  1002.50
# B              1.0  1002.0       NaN  1002.0  1002.00  1002.0  1002.00
# C              2.0  1004.5  0.707107  1004.0  1004.25  1004.5  1004.75
#
#                 Class        ... Social Media usage hrs      Percentage        \
#             max count  mean  ...                    75%  max      count  mean
# Section                      ...
# A        1003.0   2.0  10.0  ...                   2.75  3.0        2.0  55.0
# B        1002.0   1.0  10.0  ...                   2.00  2.0        1.0  80.0
# C        1005.0   2.0  11.5  ...                   1.75  2.0        2.0  60.0
#
#
#                std   min   25%   50%   75%   max
# Section
# A         7.071068  50.0  52.5  55.0  57.5  60.0
# B              NaN  80.0  80.0  80.0  80.0  80.0
# ...

# %%
gr1.mean()
# Out:
#          Student ID  Class  Study hrs  Social Media usage hrs  Percentage
# Section
# A            1002.0   10.0        2.5                     2.5        55.0
# B            1002.0   10.0        6.0                     2.0        80.0
# C            1004.5   11.5        2.5                     1.5        60.0

# %%
gr1.aggregate(['mean','median','sum'])
# Out:
#         Student ID               Class            Study hrs             \
#               mean  median   sum  mean median sum      mean median sum
# Section
# A           1002.0  1002.0  2004  10.0   10.0  20       2.5    2.5   5
# B           1002.0  1002.0  1002  10.0   10.0  10       6.0    6.0   6
# C           1004.5  1004.5  2009  11.5   11.5  23       2.5    2.5   5
#
#         Social Media usage hrs            Percentage
#                           mean median sum       mean median  sum
# Section
# A                          2.5    2.5   5       55.0   55.0  110
# B                          2.0    2.0   2       80.0   80.0   80
# C                          1.5    1.5   3       60.0   60.0  120

# %%
gr1.get_group('B')
# Out:
#    Student ID Section  Class  Study hrs  Social Media usage hrs  Percentage
# 1        1002       B     10          6                       2          80

# %%
gr1.get_group('A')
# Out:
#    Student ID Section  Class  Study hrs  Social Media usage hrs  Percentage
# 0        1001       A     10          2                       3          50
# 2        1003       A     10          3                       2          60

# %%
list(gr1)
# Out:
# [('A',
#      Student ID Section  Class  Study hrs  Social Media usage hrs  Percentage
#   0        1001       A     10          2                       3          50
#   2        1003       A     10          3                       2          60),
#  ('B',
#      Student ID Section  Class  Study hrs  Social Media usage hrs  Percentage
#   1        1002       B     10          6                       2          80),
#  ('C',
#      Student ID Section  Class  Study hrs  Social Media usage hrs  Percentage
#   3        1004       C     11          0                       1          45
#   4        1005       C     12          5                       2          75)]

# %%
dict(list(gr1))
# Out:
# {'A':    Student ID Section  Class  Study hrs  Social Media usage hrs  Percentage
#  0        1001       A     10          2                       3          50
#  2        1003       A     10          3                       2          60,
#  'B':    Student ID Section  Class  Study hrs  Social Media usage hrs  Percentage
#  1        1002       B     10          6                       2          80,
#  'C':    Student ID Section  Class  Study hrs  Social Media usage hrs  Percentage
#  3        1004       C     11          0                       1          45
#  4        1005       C     12          5                       2          75}
