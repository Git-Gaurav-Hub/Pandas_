# %%
import pandas as pd

# %%
df=pd.read_csv('D:\\DUCAT\\Pandas\\Fortune_13.csv')
df
# Out:
#    ID Values             Name             Industry  Inception       Revenue  \
# 0   1    Yes          Lamtone          IT Services       2009  $11,757,018
# 1   2    Yes        Stripfind   Financial Services       2010  $12,329,371
# 2   3    Yes  Canecorporation               Health       2012  $10,597,009
# 3   4    Yes         Mattouch          IT Services       2013  $14,026,934
# 4   5    Yes        Techdrill                  NaN       2009  $10,573,990
# 5   6    Yes         Techline                  NaN       2006  $13,898,119
# 6   7    Yes          Cityace                  NaN       2010   $9,254,614
# 7   8    Yes   Kayelectronics                  NaN       2009   $9,451,943
# 8   9    Yes          Ganzlax          IT Services       2011  $14,001,180
# 9  10    Yes      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit         Growth
# 0  6,482,465 Dollars   5274553            30%
# 1    916,455 Dollars  11412916            20%
# ...

# %%
df=pd.read_csv('D:\\DUCAT\\Pandas\\Fortune_13.csv',na_values='Not available')
df
# Out:
#    ID Values             Name             Industry  Inception       Revenue  \
# 0   1    Yes          Lamtone          IT Services       2009  $11,757,018
# 1   2    Yes        Stripfind   Financial Services       2010  $12,329,371
# 2   3    Yes  Canecorporation               Health       2012  $10,597,009
# 3   4    Yes         Mattouch          IT Services       2013  $14,026,934
# 4   5    Yes        Techdrill                  NaN       2009  $10,573,990
# 5   6    Yes         Techline                  NaN       2006  $13,898,119
# 6   7    Yes          Cityace                  NaN       2010   $9,254,614
# 7   8    Yes   Kayelectronics                  NaN       2009   $9,451,943
# 8   9    Yes          Ganzlax          IT Services       2011  $14,001,180
# 9  10    Yes      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit        Growth
# 0  6,482,465 Dollars   5274553           30%
# 1    916,455 Dollars  11412916           20%
# ...

# %%
df=pd.read_csv('D:\\DUCAT\\Pandas\\Fortune_13.csv',na_values=['Not available','hope so good'])
df
# Out:
#    ID Values             Name             Industry  Inception       Revenue  \
# 0   1    Yes          Lamtone          IT Services       2009  $11,757,018
# 1   2    Yes        Stripfind   Financial Services       2010  $12,329,371
# 2   3    Yes  Canecorporation               Health       2012  $10,597,009
# 3   4    Yes         Mattouch          IT Services       2013  $14,026,934
# 4   5    Yes        Techdrill                  NaN       2009  $10,573,990
# 5   6    Yes         Techline                  NaN       2006  $13,898,119
# 6   7    Yes          Cityace                  NaN       2010   $9,254,614
# 7   8    Yes   Kayelectronics                  NaN       2009   $9,451,943
# 8   9    Yes          Ganzlax          IT Services       2011  $14,001,180
# 9  10    Yes      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# ...

# %%
df=pd.read_csv('D:\\DUCAT\\Pandas\\Fortune_13.csv',na_values={'Growth':'Not available'})
df
# Out:
#    ID Values             Name             Industry  Inception       Revenue  \
# 0   1    Yes          Lamtone          IT Services       2009  $11,757,018
# 1   2    Yes        Stripfind   Financial Services       2010  $12,329,371
# 2   3    Yes  Canecorporation               Health       2012  $10,597,009
# 3   4    Yes         Mattouch          IT Services       2013  $14,026,934
# 4   5    Yes        Techdrill                  NaN       2009  $10,573,990
# 5   6    Yes         Techline                  NaN       2006  $13,898,119
# 6   7    Yes          Cityace                  NaN       2010   $9,254,614
# 7   8    Yes   Kayelectronics                  NaN       2009   $9,451,943
# 8   9    Yes          Ganzlax          IT Services       2011  $14,001,180
# 9  10    Yes      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit        Growth
# 0  6,482,465 Dollars   5274553           30%
# 1    916,455 Dollars  11412916           20%
# ...

# %%
df=pd.read_csv('D:\\DUCAT\\Pandas\\Fortune_13.csv',na_values={'Growth':'Not available','Growth':'hope so good'})
df
# Out:
#    ID Values             Name             Industry  Inception       Revenue  \
# 0   1    Yes          Lamtone          IT Services       2009  $11,757,018
# 1   2    Yes        Stripfind   Financial Services       2010  $12,329,371
# 2   3    Yes  Canecorporation               Health       2012  $10,597,009
# 3   4    Yes         Mattouch          IT Services       2013  $14,026,934
# 4   5    Yes        Techdrill                  NaN       2009  $10,573,990
# 5   6    Yes         Techline                  NaN       2006  $13,898,119
# 6   7    Yes          Cityace                  NaN       2010   $9,254,614
# 7   8    Yes   Kayelectronics                  NaN       2009   $9,451,943
# 8   9    Yes          Ganzlax          IT Services       2011  $14,001,180
# 9  10    Yes      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit         Growth
# 0  6,482,465 Dollars   5274553            30%
# 1    916,455 Dollars  11412916            20%
# ...

# %%
df=pd.read_csv('D:\\DUCAT\\Pandas\\Fortune_13.csv',keep_default_na=False)
df
# Out:
#    ID Values             Name             Industry  Inception       Revenue  \
# 0   1    Yes          Lamtone          IT Services       2009  $11,757,018
# 1   2    Yes        Stripfind   Financial Services       2010  $12,329,371
# 2   3    Yes  Canecorporation               Health       2012  $10,597,009
# 3   4    Yes         Mattouch          IT Services       2013  $14,026,934
# 4   5    Yes        Techdrill                   NA       2009  $10,573,990
# 5   6    Yes         Techline                   NA       2006  $13,898,119
# 6   7    Yes          Cityace                   NA       2010   $9,254,614
# 7   8    Yes   Kayelectronics                            2009   $9,451,943
# 8   9    Yes          Ganzlax          IT Services       2011  $14,001,180
# 9  10    Yes      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit         Growth
# 0  6,482,465 Dollars   5274553            30%
# 1    916,455 Dollars  11412916            20%
# ...

# %%
df=pd.read_csv('D:\\DUCAT\\Pandas\\Fortune_13.csv',keep_default_na=True)
df
# Out:
#    ID Values             Name             Industry  Inception       Revenue  \
# 0   1    Yes          Lamtone          IT Services       2009  $11,757,018
# 1   2    Yes        Stripfind   Financial Services       2010  $12,329,371
# 2   3    Yes  Canecorporation               Health       2012  $10,597,009
# 3   4    Yes         Mattouch          IT Services       2013  $14,026,934
# 4   5    Yes        Techdrill                  NaN       2009  $10,573,990
# 5   6    Yes         Techline                  NaN       2006  $13,898,119
# 6   7    Yes          Cityace                  NaN       2010   $9,254,614
# 7   8    Yes   Kayelectronics                  NaN       2009   $9,451,943
# 8   9    Yes          Ganzlax          IT Services       2011  $14,001,180
# 9  10    Yes      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit         Growth
# 0  6,482,465 Dollars   5274553            30%
# 1    916,455 Dollars  11412916            20%
# ...

# %%
df=pd.read_csv('D:\\DUCAT\\Pandas\\Fortune_14.csv') 
df
# Out:
#    ID Values             Name             Industry  Inception       Revenue  \
# 0   1    Yes          Lamtone          IT Services       2009  $11,757,018
# 1   2    Yes        Stripfind   Financial Services       2010  $12,329,371
# 2   3     NO  Canecorporation               Health       2012  $10,597,009
# 3   4    Yes         Mattouch          IT Services       2013  $14,026,934
# 4   5    Yes        Techdrill               Health       2009  $10,573,990
# 5   6    Yes         Techline               Health       2006  $13,898,119
# 6   7     NO          Cityace               Health       2010   $9,254,614
# 7   8    Yes   Kayelectronics               Health       2009   $9,451,943
# 8   9     NO          Ganzlax          IT Services       2011  $14,001,180
# 9  10    Yes      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# ...

# %%
df=pd.read_csv('D:\\DUCAT\\Pandas\\Fortune_14.csv',na_filter=False)
df
# Out:
#    ID Values             Name             Industry  Inception       Revenue  \
# 0   1    Yes          Lamtone          IT Services       2009  $11,757,018
# 1   2    Yes        Stripfind   Financial Services       2010  $12,329,371
# 2   3     NO  Canecorporation               Health       2012  $10,597,009
# 3   4    Yes         Mattouch          IT Services       2013  $14,026,934
# 4   5    Yes        Techdrill               Health       2009  $10,573,990
# 5   6    Yes         Techline               Health       2006  $13,898,119
# 6   7     NO          Cityace               Health       2010   $9,254,614
# 7   8    Yes   Kayelectronics               Health       2009   $9,451,943
# 8   9     NO          Ganzlax          IT Services       2011  $14,001,180
# 9  10    Yes      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# ...

# %%
df1=pd.read_csv('D:\\DUCAT\\Pandas\\Fortune_15.csv')
df1
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill                  NaN       2009  $10,573,990
# 5   6         Techline                  NaN       2006  $13,898,119
# 6   7          Cityace                  NaN       2010   $9,254,614
# 7   8   Kayelectronics                  NaN       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit         Growth
# 0  6,482,465 Dollars   5274553            30%
# 1    916,455 Dollars  11412916            20%
# 2  7,591,189 Dollars   3005820             7%
# ...

# %%
df1.isnull()
# Out:
#       ID   Name  Industry  Inception  Revenue  Expenses  Profit  Growth
# 0  False  False     False      False    False     False   False   False
# 1  False  False     False      False    False     False   False   False
# 2  False  False     False      False    False     False   False   False
# 3  False  False     False      False    False     False   False    True
# 4  False  False      True      False    False     False   False   False
# 5  False  False      True      False    False     False   False    True
# 6  False  False      True      False    False     False   False   False
# 7  False  False      True      False    False     False   False   False
# 8  False  False     False      False    False      True   False   False
# 9  False  False     False      False    False     False   False   False

# %%
df1.isnull().sum()
# Out:
# ID           0
# Name         0
# Industry     4
# Inception    0
# Revenue      0
# Expenses     1
# Profit       0
# Growth       2
# dtype: int64

# %%
df1.isnull().sum().sum()
# Out:
# 7

# %%
df1.notnull()
# Out:
#      ID  Name  Industry  Inception  Revenue  Expenses  Profit  Growth
# 0  True  True      True       True     True      True    True    True
# 1  True  True      True       True     True      True    True    True
# 2  True  True      True       True     True      True    True    True
# 3  True  True      True       True     True      True    True   False
# 4  True  True     False       True     True      True    True    True
# 5  True  True     False       True     True      True    True   False
# 6  True  True     False       True     True      True    True    True
# 7  True  True     False       True     True      True    True    True
# 8  True  True      True       True     True     False    True    True
# 9  True  True      True       True     True      True    True    True

# %%
df1.notnull().sum()
# Out:
# ID           10
# Name         10
# Industry      6
# Inception    10
# Revenue      10
# Expenses      9
# Profit       10
# Growth        8
# dtype: int64

# %%
df1.notnull().sum().sum()
# Out:
# 73

# %%
df=pd.read_csv('D:\\DUCAT\\Pandas\\Fortune_16.csv')
df
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill                  NaN       2009  $10,573,990
# 5   6         Techline            no values       2006  $13,898,119
# 6   7          Cityace                  NaN       2010   $9,254,614
# 7   8   Kayelectronics                  NaN       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit         Growth
# 0  6,482,465 Dollars   5274553            30%
# 1    916,455 Dollars  11412916            20%
# 2  7,591,189 Dollars   3005820             7%
# ...

# %%
df.dropna()
# Out:
#    ID Values             Name             Industry  Inception       Revenue  \
# 0   1    Yes          Lamtone          IT Services       2009  $11,757,018
# 1   2    Yes        Stripfind   Financial Services       2010  $12,329,371
# 2   3    Yes  Canecorporation               Health       2012  $10,597,009
# 3   4    Yes         Mattouch          IT Services       2013  $14,026,934
# 9  10    Yes      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# 9  5,635,276 Dollars   5453060     7%

# %%
df.dropna(axis=1)
# Out:
#    ID Values             Name  Inception       Revenue    Profit  \
# 0   1    Yes          Lamtone       2009  $11,757,018    5274553
# 1   2    Yes        Stripfind       2010  $12,329,371   11412916
# 2   3    Yes  Canecorporation       2012  $10,597,009    3005820
# 3   4    Yes         Mattouch       2013  $14,026,934    6597557
# 4   5    Yes        Techdrill       2009  $10,573,990    3138627
# 5   6    Yes         Techline       2006  $13,898,119    8427816
# 6   7    Yes          Cityace       2010   $9,254,614    3005116
# 7   8    Yes   Kayelectronics       2009   $9,451,943    5573830
# 8   9    Yes          Ganzlax       2011  $14,001,180   11901180
# 9  10    Yes      Trantraxlax       2011  $11,088,336    5453060
#
#           Growth
# 0            30%
# 1            20%
# 2             7%
# 3            26%
# 4  Not available
# 5   hope so good
# 6             6%
# 7             4%
# 8            18%
# 9             7%

# %%
df.dropna(axis=0)
# Out:
#    ID Values             Name             Industry  Inception       Revenue  \
# 0   1    Yes          Lamtone          IT Services       2009  $11,757,018
# 1   2    Yes        Stripfind   Financial Services       2010  $12,329,371
# 2   3    Yes  Canecorporation               Health       2012  $10,597,009
# 3   4    Yes         Mattouch          IT Services       2013  $14,026,934
# 9  10    Yes      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# 9  5,635,276 Dollars   5453060     7%

# %%
df.dropna(axis=0,how='any')
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit         Growth
# 0  6,482,465 Dollars   5274553            30%
# 1    916,455 Dollars  11412916            20%
# 2  7,591,189 Dollars   3005820             7%
# 3  7,429,377 Dollars   6597557  not available
# 9  5,635,276 Dollars   5453060             7%

# %%
df=pd.read_csv('D:\\DUCAT\\Pandas\\Fortune_16.csv')
df
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill                  NaN       2009  $10,573,990
# 5   6         Techline            no values       2006  $13,898,119
# 6   7          Cityace                  NaN       2010   $9,254,614
# 7   8   Kayelectronics                  NaN       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit  yup
# 0  6,482,465 Dollars   5274553  NaN
# 1    916,455 Dollars  11412916  NaN
# 2  7,591,189 Dollars   3005820  NaN
# 3  7,429,377 Dollars   6597557  NaN
# ...

# %%
df.dropna(axis=1,how='all')
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill                  NaN       2009  $10,573,990
# 5   6         Techline            no values       2006  $13,898,119
# 6   7          Cityace                  NaN       2010   $9,254,614
# 7   8   Kayelectronics                  NaN       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit
# 0  6,482,465 Dollars   5274553
# 1    916,455 Dollars  11412916
# 2  7,591,189 Dollars   3005820
# 3  7,429,377 Dollars   6597557
# 4  7,435,363 Dollars   3138627
# ...

# %%
df.dropna(thresh=7)
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill                  NaN       2009  $10,573,990
# 5   6         Techline            no values       2006  $13,898,119
# 6   7          Cityace                  NaN       2010   $9,254,614
# 7   8   Kayelectronics                  NaN       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit
# 0  6,482,465 Dollars   5274553
# 1    916,455 Dollars  11412916
# 2  7,591,189 Dollars   3005820
# 3  7,429,377 Dollars   6597557
# 4  7,435,363 Dollars   3138627
# ...

# %%
df.dropna(subset=['Expenses'])
# Out:
#    ID Values             Name             Industry  Inception       Revenue  \
# 0   1    Yes          Lamtone          IT Services       2009  $11,757,018
# 1   2    Yes        Stripfind   Financial Services       2010  $12,329,371
# 2   3    Yes  Canecorporation               Health       2012  $10,597,009
# 3   4    Yes         Mattouch          IT Services       2013  $14,026,934
# 4   5    Yes        Techdrill                  NaN       2009  $10,573,990
# 5   6    Yes         Techline                  NaN       2006  $13,898,119
# 6   7    Yes          Cityace                  NaN       2010   $9,254,614
# 7   8    Yes   Kayelectronics                  NaN       2009   $9,451,943
# 9  10    Yes      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit         Growth
# 0  6,482,465 Dollars   5274553            30%
# 1    916,455 Dollars  11412916            20%
# 2  7,591,189 Dollars   3005820             7%
# ...

# %%
df=pd.read_csv('D:\\DUCAT\\Pandas\\Fortune_09.csv')
df
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill                  NaN       2009  $10,573,990
# 5   6         Techline            no values       2006  $13,898,119
# 6   7          Cityace                  NaN       2010   $9,254,614
# 7   8   Kayelectronics                  NaN       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit
# 0  6,482,465 Dollars   5274553
# 1    916,455 Dollars  11412916
# 2  7,591,189 Dollars   3005820
# 3  7,429,377 Dollars   6597557
# 4  7,435,363 Dollars   3138627
# ...

# %%
df.dropna(inplace=True) # update the dataframe
df
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 5   6         Techline            no values       2006  $13,898,119
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit
# 0  6,482,465 Dollars   5274553
# 1    916,455 Dollars  11412916
# 2  7,591,189 Dollars   3005820
# 3  7,429,377 Dollars   6597557
# 5  5,470,303 Dollars   8427816
# 9  5,635,276 Dollars   5453060

# %%
df.dropna(inplace=False) # create a new dataframe
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 5   6         Techline            no values       2006  $13,898,119
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit
# 0  6,482,465 Dollars   5274553
# 1    916,455 Dollars  11412916
# 2  7,591,189 Dollars   3005820
# 3  7,429,377 Dollars   6597557
# 5  5,470,303 Dollars   8427816
# 9  5,635,276 Dollars   5453060
