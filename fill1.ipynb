# %%
import pandas as pd

# %%
df=pd.read_csv('D:\\DUCAT\\Pandas\\Fortune_15.csv')
df
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill                  NaN       2009  $10,573,990
# 5   6         Techline                  NaN       2006  $13,898,119
# 6   7          Cityace                  NaN       2010   $9,254,614
# 7   8   Kayelectronics                  NaN       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit         Growth
# 0  6,482,465 Dollars   5274553            30%
# 1    916,455 Dollars  11412916            20%
# 2  7,591,189 Dollars   3005820             7%
# ...

# %%
df.dropna(subset=['Growth'])
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 6   7          Cityace                  NaN       2010   $9,254,614
# 7   8   Kayelectronics                  NaN       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 6  6,249,498 Dollars   3005116     6%
# 7  3,878,113 Dollars   5573830     4%
# 8                NaN  11901180    18%
# 9  5,635,276 Dollars   5453060     7%

# %%
df=pd.read_csv('D:\\DUCAT\\Pandas\\Fortune_15.csv',na_values='not available')
df
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill                  NaN       2009  $10,573,990
# 5   6         Techline                  NaN       2006  $13,898,119
# 6   7          Cityace                  NaN       2010   $9,254,614
# 7   8   Kayelectronics                  NaN       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    NaN
# ...

# %%
df.fillna(1234)
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill                 1234       2009  $10,573,990
# 5   6         Techline                 1234       2006  $13,898,119
# 6   7          Cityace                 1234       2010   $9,254,614
# 7   8   Kayelectronics                 1234       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557   1234
# ...

# %%
df.fillna({"Industry":"TCS","Expenses":"530000 Dollars","Growth":'34%'})
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill                  TCS       2009  $10,573,990
# 5   6         Techline                  TCS       2006  $13,898,119
# 6   7          Cityace                  TCS       2010   $9,254,614
# 7   8   Kayelectronics                  TCS       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    34%
# ...

# %%
df=pd.read_csv('D:\\DUCAT\\Pandas\\Fortune_15.csv')
df
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill                  NaN       2009  $10,573,990
# 5   6         Techline                  NaN       2006  $13,898,119
# 6   7          Cityace                  NaN       2010   $9,254,614
# 7   8   Kayelectronics                  NaN       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit         Growth
# 0  6,482,465 Dollars   5274553            30%
# 1    916,455 Dollars  11412916            20%
# 2  7,591,189 Dollars   3005820             7%
# ...

# %%
df.fillna(method='ffill',axis=1)
# Out:
#    ID             Name             Industry Inception       Revenue  \
# 0   1          Lamtone          IT Services      2009  $11,757,018
# 1   2        Stripfind   Financial Services      2010  $12,329,371
# 2   3  Canecorporation               Health      2012  $10,597,009
# 3   4         Mattouch          IT Services      2013  $14,026,934
# 4   5        Techdrill            Techdrill      2009  $10,573,990
# 5   6         Techline             Techline      2006  $13,898,119
# 6   7          Cityace              Cityace      2010   $9,254,614
# 7   8   Kayelectronics       Kayelectronics      2009   $9,451,943
# 8   9          Ganzlax          IT Services      2011  $14,001,180
# 9  10      Trantraxlax  Government Services      2011  $11,088,336
#
#             Expenses    Profit         Growth
# 0  6,482,465 Dollars   5274553            30%
# 1    916,455 Dollars  11412916            20%
# 2  7,591,189 Dollars   3005820             7%
# ...

# %%
df.fillna(method='ffill',axis=0)
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill          IT Services       2009  $10,573,990
# 5   6         Techline          IT Services       2006  $13,898,119
# 6   7          Cityace          IT Services       2010   $9,254,614
# 7   8   Kayelectronics          IT Services       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit         Growth
# 0  6,482,465 Dollars   5274553            30%
# 1    916,455 Dollars  11412916            20%
# 2  7,591,189 Dollars   3005820             7%
# ...

# %%
df.fillna(limit=2,axis=0,method='bfill')
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill                  NaN       2009  $10,573,990
# 5   6         Techline                  NaN       2006  $13,898,119
# 6   7          Cityace          IT Services       2010   $9,254,614
# 7   8   Kayelectronics          IT Services       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit         Growth
# 0  6,482,465 Dollars   5274553            30%
# 1    916,455 Dollars  11412916            20%
# 2  7,591,189 Dollars   3005820             7%
# ...

# %%
df.isnull()
# Out:
#       ID   Name  Industry  Inception  Revenue  Expenses  Profit  Growth
# 0  False  False     False      False    False     False   False   False
# 1  False  False     False      False    False     False   False   False
# 2  False  False     False      False    False     False   False   False
# 3  False  False     False      False    False     False   False    True
# 4  False  False      True      False    False     False   False   False
# 5  False  False      True      False    False     False   False    True
# 6  False  False      True      False    False     False   False   False
# 7  False  False      True      False    False     False   False   False
# 8  False  False     False      False    False      True   False   False
# 9  False  False     False      False    False     False   False   False

# %%
df.isnull().sum()
# Out:
# ID           0
# Name         0
# Industry     4
# Inception    0
# Revenue      0
# Expenses     1
# Profit       0
# Growth       2
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 7

# %%
df.fillna(limit=2,axis=0,method='pad',inplace=True)
df
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill          IT Services       2009  $10,573,990
# 5   6         Techline          IT Services       2006  $13,898,119
# 6   7          Cityace          IT Services       2010   $9,254,614
# 7   8   Kayelectronics          IT Services       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit         Growth
# 0  6,482,465 Dollars   5274553            30%
# 1    916,455 Dollars  11412916            20%
# 2  7,591,189 Dollars   3005820             7%
# ...
